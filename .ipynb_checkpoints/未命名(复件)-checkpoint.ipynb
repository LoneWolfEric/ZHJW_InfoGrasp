# %%
from PIL import Image
import numpy as np
import pytesseract
import cv2
import matplotlib.pyplot as plt

# %%
img = Image.open('captcha.jpg')

# %%
plt.figure("Image") # 图像窗口名称
plt.imshow(img)

# %%
img = np.asarray(img)
img = np.array(img)

# %%
img[40,:,2]
# Out:
# array([123, 174, 184, 188, 200, 201, 206, 202, 201, 197, 194, 195, 195,
#        199, 201, 203,  58,   5,   0,  14,   9,   2,   0,  10,  19, 121,
#        205, 211, 196, 204, 209, 197, 206, 206, 206, 207, 207, 208, 208,
#        208, 172,  24,   0, 116, 215, 207, 227, 203, 211, 127,  64,   2,
#          6,   3,  24,  49,  84, 150, 133, 164, 172, 149, 108,  62,   0,
#          5,  14,  22,  66, 133, 186, 203, 202, 177, 208, 157, 141, 162,
#        151, 150, 227, 217, 211, 177, 119, 134,  37,  53,  66, 116,  77,
#         56,  20,   0,   0,   0,   0,   0,   0,   0,  30,  52, 108,  71,
#         43,  30,  46,  16,  19,  80, 118, 153, 194, 222, 211, 191, 159,
#        120, 106,  94,  96, 118, 108, 123, 162, 108,  16,  26,   0,   0,
#         13,  80, 176, 228, 234, 243, 249, 255, 255, 248, 238, 233, 230,
#        230, 244, 243, 241, 239, 239, 240, 242, 244, 238, 242, 246, 246,
#        244, 243, 246, 250, 243, 249, 255, 246, 242, 251, 246, 245, 249,
#        249, 249, 250, 250, 251, 251, 251, 246, 245, 230, 115], dtype=uint8)

# %%
img = Image.open('captcha.jpg')
img = np.asarray(img)
img = np.array(img)

for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        if ( img[i,j,0] < 60 ) and ( img[i,j,1] < 60 ) and ( img[i,j,2] < 60 ):
            img[i,j] = np.array([200,200,200])

plt.imshow(img)

# %%
content = pytesseract.image_to_string(img)
content
# Out:
# ''

# %%
content
