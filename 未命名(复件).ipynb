# %%
from PIL import Image
import numpy as np
import pytesseract
import cv2
import matplotlib.pyplot as plt

# %%
img = Image.open('captcha.jpg')

# %%
plt.figure("Image") # 图像窗口名称
plt.imshow(img)

# %%
img = np.asarray(img)
img = np.array(img)

# %%
img[30,:,2]
# Out:
# array([122, 172, 182, 185, 197, 199, 204, 201, 199, 195, 192, 193, 193,
#        197, 199, 201, 199, 199, 199, 200, 200, 201, 201, 201, 187, 215,
#        156, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200,  71,
#        110, 157, 204, 223, 210, 205, 192, 146,  98,  52, 200,   0,   0,
#          0,   0,   0,   0,  42,  80, 126, 168, 188, 183, 153, 122,  42,
#          0,   5,   6,  26,  54,  99, 218, 193, 182, 173, 128, 143, 193,
#        196, 219, 197, 175,  98,  68,  69,  92, 140, 132, 113, 102,  42,
#         24,  28,  29,  60,  78, 209, 226, 228, 230, 223, 215, 208, 113,
#         25,  16,   0,  18,  35,  92, 220, 235, 252, 189, 117,  65,   0,
#          0,  13,  67, 177, 250, 255, 226, 132,  58,   0,   0,   0,  28,
#        101, 193, 244, 248, 239, 235, 228, 230, 237, 245, 247, 244, 235,
#        230, 240, 240, 240, 241, 241, 242, 242, 242, 242, 242, 242, 243,
#        243, 244, 244, 244, 245, 245, 245, 246, 246, 247, 247, 247, 247,
#        247, 247, 248, 248, 249, 249, 249, 245, 244, 230, 115], dtype=uint8)

# %%
img = Image.open('captcha.jpg')
img = np.asarray(img)
img = np.array(img)

for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        if ( img[i,j,0] < 100 ) and ( img[i,j,1] < 100 ) and ( img[i,j,2] < 100 ):
            img[i,j] = np.array([200,200,200])

plt.imshow(img)

# %%
content = pytesseract.image_to_string(img)
content
# Out:
# ''

# %%
content
